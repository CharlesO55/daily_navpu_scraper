# %%
from pathlib import Path
import pandas as pd

# %%
filepaths = [str(fpath) for fpath in Path("../data").rglob("*.csv")]
filepaths
# Out:
# ['..\\data\\navpu\\aub\\Aub_Dollar_Money_Market_Fund.csv',
#  '..\\data\\navpu\\aub\\Aub_Equity_Investment_Trust_Fund.csv',
#  '..\\data\\navpu\\aub\\Aub_Gold_Dollar_Fund.csv',
#  '..\\data\\navpu\\aub\\Aub_Peso_Investment_Trust_Fund.csv',
#  '..\\data\\navpu\\aub\\Aub_Peso_Money_Market_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_China_Equity_Feeder_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Dividend_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Dollar_Bond_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Dollar_Money_Market_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Equity_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Equity_Index_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Esg_Equity_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Europe_Equity_Feeder_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Focused_Equity_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Global_Em_Equity_Index_Feeder_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Global_Equity_Index_Feeder_Fund.csv',
#  '..\\data\\navpu\\bdo\\Bdo_Institutional_Equity_Fund.csv',
# ...

# %%
# df = pd.read_csv(filepaths[1], index_col=0, names=['date', 'value'])
df = pd.read_csv("test.csv", index_col=0, names=['date', 'value'])
df.drop_duplicates(inplace=True)
# df.to_csv(filepaths[0])
df
# Out:
#                 value
# date
# date            value
# 2026-03-18  105.60231
# 2026-03-22  105.60727
# 2026-03-23  105.64589
# 2026-03-24  105.65628
# 2026-03-25  105.66689
# 2026-03-26  105.67555
# 2026-03-29  105.70469
# 2026-03-30  105.71496
# 2026-03-31  105.72349
